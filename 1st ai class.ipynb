# %% [markdown]
# <a href="https://colab.research.google.com/github/jatinthakur-star/ai-class/blob/main/1st%20ai%20class.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("********* BIODATA ********")
print()
print("name          : jatin")
# my name
print("Father's name : narinder singh")
# father's name
print("Mother name   : jeevan jyoti")
# mother 'name
print("age           : 18")
# my age
print("sister age      : 13 yrs old")
#  sister age
print("qualification : 12th pass")
''' my qualifcation i passed
class 12th in 2026 session '''
print("occupation    : student")
print("father's occupation : BSF")
print("mobile no.    : 977XXX5762")
print("address       : pathankot")
print()
print("*************************")
# Out:
# ********* BIODATA ********
#
# name          : jatin
# Father's name : narinder singh
# Mother name   : jeevan jyoti
# age           : 18
# sister age      : 13 yrs old
# qualification : 12th pass
# occupation    : student
# father's occupation : BSF
# mobile no.    : 977XXX5762
# address       : pathankot
#
# *************************

# %%
print("***** bill *****")
print()
print("pizza : 500")
print("burger :100")
print("cold drink : 100")
print("total: 700")
print("for any query call : 1800XXXXX374")
print()
print("**************")
# Out:
# ***** bill *****
#
# pizza : 500
# burger :100
# cold drink : 100
# total: 700
# for any query call : 1800XXXXX374
#
# **************

# %%
my_name= "Jatin"
print("Name :",my_name)
my_age="18"
print("age :",my_age)
my_qualification="12 pass"
print("qualification :",my_qualification)
my_occupation="student"
print("occupation :",my_occupation)
father_name="Narinder singh"
print("father name :",father_name)
father_occupation="BSF"
print("father occupation :",father_occupation)
mother_name= "Jeevan jyoti"
print("mother name :", mother_name)
mother_occupation ="housewife"
print("mother occupation :",mother_occupation)
sister_name = "Janvi"
print("sister name :", sister_name)
# Out:
# Name : Jatin
# age : 18
# qualification : 12 pass
# occupation : student
# father name : Narinder singh
# father occupation : BSF
# mother name : Jeevan jyoti
# mother occupation : housewife
# sister name : Janvi

# %%
first_no =8
second_no=4
add=first_no+second_no
sub=first_no-second_no
mult=first_no*second_no
div=first_no/second_no
remin=first_no%second_no
print("addition of two numbers :", add)
print("subtraction of two numbers :", sub)
print("multiplication of two numbers :",mult)
print("division of two numbers :", div)
print("reminder of two numbers :",remin)
# Out:
# addition of two numbers : 12
# subtraction of two numbers : 4
# multiplication of two numbers : 32
# division of two numbers : 2.0
# reminder of two numbers : 0

# %%
print("*******Bill********")
price_of_burger=500
price_of_pizza=600
price_of_colddrink=100
total_bill=price_of_burger+price_of_pizza+price_of_colddrink
print("burger:", price_of_burger)
print("pizza:", price_of_pizza)
print("colddrink:",price_of_colddrink)
discount=total_bill*10/100
print("discount",discount)
print("Total bill:",total_bill)
payable_bill=total_bill-discount
print("payable bill :",payable_bill)
print("**************")
# Out:
# *******Bill********
# burger: 500
# pizza: 600
# colddrink: 100
# discount 120.0
# Total bill: 1200
# payable bill : 1080.0
# **************

# %%
p=5000
r=5
t=3
si=p*r*t/100
print("si : ",si)
# Out:
# si :  750.0

# %%
print("******bill******")
print("MOST WELCOME IN OUR CAFETERIA")
bag=400
bootle=200
notebook=200
clothes=500
shoes=900
print("bag : ",bag)
bag_discount=400*30/100
final_price_for_bag=bag-bag_discount
print("final price for bag :",final_price_for_bag)
print("bootle : ",bootle)
print("notebook :",notebook)
print("clothes :",clothes)
final_price_for_clothes=clothes-clothes*20/100
print("final price for clothes : ",final_price_for_clothes)
print("shoes : ",shoes)
final_price_for_shoes=shoes-shoes*15/100
print("final price for shoes :",final_price_for_shoes)
total_bill=final_price_for_bag+final_price_for_clothes+bootle+bootle+final_price_for_shoes
print("total bill : ",total_bill)
discount=total_bill*10/100
print("discount : ",discount)
payable_bill=total_bill-discount
print("payable bill :",payable_bill)
print("THANKS FOR VISITING OUR CAFETERIA , COME BACK AGAIN")
print("************END oF THE BILL************")
# Out:
# ******bill******
# MOST WELCOME IN OUR CAFETERIA
# bag :  400
# final price for bag : 280.0
# bootle :  200
# notebook : 200
# clothes : 500
# final price for clothes :  400.0
# shoes :  900
# final price for shoes : 765.0
# total bill :  1845.0
# discount :  184.5
# payable bill : 1660.5
# THANKS FOR VISITING OUR CAFETERIA
# ************END oF THE BILL************

# %%
p=5000
r=5
t=3
t2_days=20
t2_days_in_month=t2_days/30
si_month=p*r*t/100
si_t2_days=p*r*t2_days_in_month/100
total_si=si_month+si_t2_days
print("total si :",total_si)
# Out:
# total si : 916.6666666666666

# %%
p=int(input("enter the principle amount :"))
r=int(input("enter rate :"))
t=int(input("enter time in month :"))
t_in_days=int(input("enter time in days :"))
t_in_days_in_month=t_in_days/30
si_month=p*r*t/100
si_t_in_days=p*r*t_in_days_in_month/100
total_si=si_month+si_t_in_days
print("total si : ",total_si)
# Out:
# enter the principle amount :4000
# enter rate :3
# enter time in month :2
# enter time in days :20
# total si :  320.0

# %%
price_of_burger=int(input("enter the price of burger :"))
price_of_pizza=int(input("enter the price of pizza :"))
price_of_momos=int(input("enter the price of momos :"))
qty_of_burger=int(input("enter the quantity of burger :"))
qty_of_pizza=int(input("enter the quantity of pizza :"))
qty_of_momos=int(input("enter the quantity of momos :"))

total_bill=price_of_burger*qty_of_burger+price_of_pizza*qty_of_pizza+price_of_momos*qty_of_momos
print("*****BILL******")
print("burger :",price_of_burger)
discount=price_of_burger*10/100
print("discount :", discount)
print("qty of burger : " ,qty_of_burger)
print("pizza :",price_of_pizza)
discount=price_of_pizza*20/100
print("discount :",discount)
print("qty of pizza :",qty_of_pizza)
print("momos :" , price_of_momos)
discount=price_of_momos*20/100
print("discount :",discount)
print("qty of momos :",qty_of_momos)
print("total bill :",total_bill)
payable_bill=total_bill-discount
print("payable bill :",payable_bill)
# Out:
# enter the price of burger :10
# enter the price of pizza :10
# enter the price of momos :10
# enter the quantity of burger :1
# enter the quantity of pizza :1
# enter the quantity of momos :1
# *****BILL******
# burger : 10
# discount : 1.0
# qty of burger :  1
# pizza : 10
# discount : 2.0
# qty of pizza : 1
# momos : 10
# discount : 2.0
# qty of momos : 1
# total bill : 30
# payable bill : 28.0

# %%
rupees_to_dollar=95.44
rupees=int(input("how much dollar($) you want to change in INR :"))
dollar=rupees/rupees_to_dollar
print("dollar :",dollar)
# Out:
# how much dollar($) you want to change in INR1000
# dollar : 10.477787091366304

# %%
dollar_to_rupees=95.44
dollar=int(input("how much INR you want to change $ DOLLAR :"))
rupees=dollar*dollar_to_rupees
print("rupees:",rupees)
# Out:
# how much INR you want to change $ DOLLAR :10
# rupees: 954.4

# %%
euro_to_rupees=109.02
rupees=int(input("how much rupees you want to change euro :"))
euro=rupees/euro_to_rupees
print("euro :",euro)
# Out:
# how much rupees you want to change euro :5000
# euro : 45.8631443771785

# %%
rupees_to_euro=109.02
euro=int(input("how much euro you want to change in INR :"))
rupees=euro*rupees_to_euro
print("rupees :",rupees)
# Out:
# how much euro you want to change in INR :100
# rupees : 10902.0

# %%
rupees_to_AUD=66.13
AUD=int(input("how much AUD($) you want to change in INR :"))
rupees=AUD*rupees_to_AUD
print("rupees :",rupees)
# Out:
# how much AUD($) you want to change in INR :100
# rupees : 6613.0

# %%
AUD_to_rupees=66.13
rupees=int(input("how much INR you want to change in AUD($)"))
AUD=rupees/AUD_to_rupees
print("AUD :", AUD)
# Out:
# how much INR you want to change in AUD($)100
# AUD : 1.5121729925903524

# %%
rupees_to_CAD=67.02
CAD=int(input("how much CAD you want to change in INR :"))
rupees=CAD*rupees_to_CAD
print("rupees :",rupees)
# Out:
# how much CAD you want to change in INR :100
# rupees : 6702.0

# %%
NGN_to_INR=0.0696
NGN=int(input("how much NGN you want to change in INR :"))
rupees=NGN*NGN_to_INR
print("rupees :",rupees)
# Out:
# how m uch NGN you want to change in INR :100000
# rupees : 6959.999999999999

# %%
NGN_to_USD=0.00073
NGN=int(input("how much NGN you want to changein USD"))
USD=NGN*NGN_to_USD
print("USD :",USD)
# Out:
# how much NGN you want to changein USD100000
# USD : 73.0

# %%
num=int(input("enter the number :"))
if num>0:
      print("+ve number")
elif num==0:
  print("it's neither +ve number nor -ve number")
else:
      print("-ve number")
# Out:
# enter the number :0
# it's neither +ve number nor -ve number

# %%
gender=input("Write your gender :")
if gender=="male":
      print("Hotel A")
else:
      print("Hotel B")
# Out:
# write your gender :male
# hotel A

# %%
gender=input("write your gender :")
age=int(input("write your age :"))
if gender=="male":
  print("hotel A")
  if age>20:
   print("first floor")
  else:
   print("second floor")
else:
  print("hotel B")
  if age>20:
   print("first floor")
  else:
    print("second floor")
# Out:
# write your gender :female
# write your age :20
# hotel B
# first floor
